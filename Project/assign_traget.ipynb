# %%
import pandas as pd

df_recipes = pd.read_csv('../dataset/recipes.csv')

# %%
add_col = ['carbohydrate_p','protein_p','fat_p']
map_to_col = ['carbohydrate','protein','fat']

# Protein - 4 calories per gram
# Fats - 9 calories per gram
# Carbs - 4 calories per gram
macronutrient_basics = [4,4,9]

for i in range(3):
    df_recipes[add_col[i]] = ((df_recipes[map_to_col[i]]*macronutrient_basics[i]/df_recipes['calories'])*100).round(1)

# %%
"""
Label 1
"""
df_recipes['Label1'] = 'Others'

c = df_recipes['carbohydrate_p']
p = df_recipes['protein_p']
f = df_recipes['fat_p']
label = df_recipes['Label1']
for i in range(df_recipes.shape[0]):
    if  c.loc[i] <= 5 and f.loc[i] >= 75:
        label.loc[i] = 'Keto'
    elif p.loc[i] >= 40 and (c.loc[i] >= 25 and c.loc[i] <= 35) and (f.loc[i] >= 25 and f.loc[i] <= 35):
        label.loc[i] = 'Fat_Loss'
    elif c.loc[i] <=20 and (p.loc[i] >= 35 and p.loc[i] <= 45) and (f.loc[i] >= 25 and f.loc[i] <= 35):
        label.loc[i] = 'Sugar_Control'

df_recipes.groupby('Label1').count()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                recipe_id  recipe_name  calories  carbohydrate   fat  protein  \
# Label1
# Fat_Loss              36           36        36            36    36       36
# Keto                  48           48        48            48    48       48
# Others              3276         3276      3276          3276  3276     3276
# Sugar_Control          5            5         5             5     5        5
#
#                carbohydrate_p  protein_p  fat_p
# Label1
# Fat_Loss                   36         36     36
# Keto                       48         48     48
# Others                   3275       3274   3274
# ...

# %%
"""
Label 1-0: Fat loss keep only protein & fat ; Sugar control keep only carb & potein
"""
df_recipes['Label1-0'] = 'Others'

c = df_recipes['carbohydrate_p']
p = df_recipes['protein_p']
f = df_recipes['fat_p']
label = df_recipes['Label1-0']
for i in range(df_recipes.shape[0]):
    if  c.loc[i] <= 5 and f.loc[i] >= 75:
        label.loc[i] = 'Keto'
    elif p.loc[i] >= 40 and (f.loc[i] >= 25 and f.loc[i] <= 35):
        label.loc[i] = 'Fat_Loss'
    elif c.loc[i] <=20 and (p.loc[i] >= 35 and p.loc[i] <= 45):
        label.loc[i] = 'Sugar_Control'

df_recipes.groupby('Label1-0').count()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                recipe_id  recipe_name  calories  carbohydrate   fat  protein  \
# Label1-0
# Fat_Loss             153          153       153           153   153      153
# Keto                  48           48        48            48    48       48
# Others              3020         3020      3020          3020  3020     3020
# Sugar_Control        144          144       144           144   144      144
#
#                carbohydrate_p  protein_p  fat_p  Label1
# Label1-0
# Fat_Loss                  153        153    153     153
# Keto                       48         48     48      48
# ...

# %%
"""
Label 1-1: Fat loss keep only protein & crab ; Sugar control keep only carb & fat
"""
df_recipes['Label1-1'] = 'Others'

c = df_recipes['carbohydrate_p']
p = df_recipes['protein_p']
f = df_recipes['fat_p']
label = df_recipes['Label1-1']
for i in range(df_recipes.shape[0]):
    if  c.loc[i] <= 5 and f.loc[i] >= 75:
        label.loc[i] = 'Keto'
    elif p.loc[i] >= 40 and (c.loc[i] >= 25 and c.loc[i] <= 35):
        label.loc[i] = 'Fat_Loss'
    elif c.loc[i] <=20 and (f.loc[i] >= 25 and f.loc[i] <= 35):
        label.loc[i] = 'Sugar_Control'

df_recipes.groupby('Label1-1').count()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                recipe_id  recipe_name  calories  carbohydrate   fat  protein  \
# Label1-1
# Fat_Loss             111          111       111           111   111      111
# Keto                  48           48        48            48    48       48
# Others              3118         3118      3118          3118  3118     3118
# Sugar_Control         88           88        88            88    88       88
#
#                carbohydrate_p  protein_p  fat_p  Label1  Label1-0
# Label1-1
# Fat_Loss                  111        111    111     111       111
# Keto                       48         48     48      48        48
# ...

# %%
"""
Label 2
"""

df_recipes['Label2'] = 'Others'
c = df_recipes['carbohydrate_p']
p = df_recipes['protein_p']
f = df_recipes['fat_p']
label = df_recipes['Label2']
for i in range(df_recipes.shape[0]):
    if  (f.loc[i] >= 70 and c.loc[i] <= 10) or (f.loc[i] >= 60 and c.loc[i] <= 5) :
        label.loc[i] = 'Keto'
#         print(df_recipes.loc[i][1])
#         print(df_recipes.loc[i][6: 9])
#         print('\n\n')
    elif p.loc[i] >= 35 and (f.loc[i] >= 15 and f.loc[i] <= 30):
        label.loc[i] = 'Fat_Loss'
    elif c.loc[i] <=26 and f.loc[i] <= 35:
        label.loc[i] = 'Sugar_Control'
        
df_recipes.groupby('Label2').count()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                recipe_id  recipe_name  calories  carbohydrate   fat  protein  \
# Label2
# Fat_Loss             264          264       264           264   264      264
# Keto                 172          172       172           172   172      172
# Others              2812         2812      2812          2812  2812     2812
# Sugar_Control        117          117       117           117   117      117
#
#                carbohydrate_p  protein_p  fat_p  Label1  Label1-0  Label1-1  \
# Label2
# Fat_Loss                  264        264    264     264       264       264
# ...

# %%
"""
Label 2-0: only change keto ratio: includes all for fat >=75 
"""

df_recipes['Label2-0'] = 'Others'
c = df_recipes['carbohydrate_p']
p = df_recipes['protein_p']
f = df_recipes['fat_p']
label = df_recipes['Label2-0']
for i in range(df_recipes.shape[0]):
    if  f.loc[i] >= 75:
        label.loc[i] = 'Keto'
#         print(df_recipes.loc[i][1])
#         print(df_recipes.loc[i][6: 9])
#         print('\n\n')
    elif p.loc[i] >= 35 and (f.loc[i] >= 15 and f.loc[i] <= 30):
        label.loc[i] = 'Fat_Loss'
    elif c.loc[i] < 26 and f.loc[i] <= 35:
        label.loc[i] = 'Sugar_Control'
        
df_recipes.groupby('Label2-0').count()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                recipe_id  recipe_name  calories  carbohydrate   fat  protein  \
# Label2-0
# Fat_Loss             264          264       264           264   264      264
# Keto                 191          191       191           191   191      191
# Others              2793         2793      2793          2793  2793     2793
# Sugar_Control        117          117       117           117   117      117
#
#                carbohydrate_p  protein_p  fat_p  Label1  Label1-0  Label1-1  \
# Label2-0
# Fat_Loss                  264        264    264     264       264       264
# ...

# %%
"""
Label 3
"""

df_recipes['Label3'] = 'Others'
c = df_recipes['carbohydrate_p']
p = df_recipes['protein_p']
f = df_recipes['fat_p']
label = df_recipes['Label3']
for i in range(df_recipes.shape[0]):
    if  f.loc[i] >= 64 and c.loc[i] <= 14 and p.loc[i] <= 25.3 :
        label.loc[i] = 'Keto'
#         print(df_recipes.loc[i][1])
#         print(df_recipes.loc[i][6: 9])
#         print('\n\n')
    elif p.loc[i] >= 35 and (f.loc[i] >= 15 and f.loc[i] <= 30):
        label.loc[i] = 'Fat_Loss'
    elif c.loc[i] < 40 and f.loc[i] <= 35:
        label.loc[i] = 'Sugar_Control'
        
df_recipes.groupby('Label3').count()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                recipe_id  recipe_name  calories  carbohydrate   fat  protein  \
# Label3
# Fat_Loss             264          264       264           264   264      264
# Keto                 209          209       209           209   209      209
# Others              2667         2667      2667          2667  2667     2667
# Sugar_Control        225          225       225           225   225      225
#
#                carbohydrate_p  protein_p  fat_p  Label1  Label1-0  Label1-1  \
# Label3
# Fat_Loss                  264        264    264     264       264       264
# ...
